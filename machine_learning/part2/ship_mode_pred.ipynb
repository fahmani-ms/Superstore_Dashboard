# %%
import mysql.connector
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="Qazule12345",
    database="shop"
)

# %%
mycursor = mydb.cursor()

# Execute SQL query to retrieve table names
mycursor.execute("SHOW TABLES")

# Fetch all table names
tables = mycursor.fetchall()

# Print the table names
for table in tables:
    print(table[0])
# Out:
# customer
# order
# order_detail
# product
# returned
# shipping

# %%
query = "SELECT `order`.`Order ID`, `Order Priority`,od.`Product ID`,p.Category,p.`Sub-Category`,od.Quantity,od.Sales,od.Discount,od.`Shipping Cost`,s.`Ship Mode`,s.Country,`Order Date`,s.`Ship Date`,Market FROM `order` JOIN shipping s on `order`.`Order ID` = s.`Order ID` right JOIN order_detail od ON `order`.`Order ID` = od.`Order ID` JOIN product p on p.`Product ID` = od.`Product ID`;"

# %%
mycursor.execute(query)
joined_data = mycursor.fetchall()

# %%
column_names = [i[0] for i in mycursor.description]

df = pd.DataFrame(joined_data, columns=column_names)

mydb.close()

# %%
df
# Out:
#            Order ID Order Priority        Product ID    Category Sub-Category  \
# 0      IZ-2014-4660         Medium  FUR-ADV-10000002   Furniture  Furnishings
# 1      MO-2012-8110         Medium  FUR-ADV-10000108   Furniture  Furnishings
# 2      RW-2012-8200         Medium  FUR-ADV-10000108   Furniture  Furnishings
# 3      LI-2011-9980           High  FUR-ADV-10000108   Furniture  Furnishings
# 4      TU-2014-4400         Medium  FUR-ADV-10000183   Furniture  Furnishings
# ...             ...            ...               ...         ...          ...
# 49665  MZ-2013-3540         Medium  TEC-STA-10004542  Technology     Machines
# 49666  GH-2014-4170         Medium  TEC-STA-10004542  Technology     Machines
# 49667   TU-2011-790         Medium  TEC-STA-10004834  Technology     Machines
# 49668  NI-2013-7410            Low  TEC-STA-10004834  Technology     Machines
# 49669  UP-2011-3730         Medium  TEC-STA-10004927  Technology     Machines
#
# ...

# %%
df.to_csv('shipmode_pred.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49670 entries, 0 to 49669
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        49670 non-null  object
#  1   Order Priority  49670 non-null  object
#  2   Product ID      49670 non-null  object
#  3   Category        49670 non-null  object
#  4   Sub-Category    49670 non-null  object
#  5   Quantity        49670 non-null  int64
#  6   Sales           49670 non-null  float64
#  7   Discount        49670 non-null  float64
#  8   Shipping Cost   49670 non-null  float64
#  9   Ship Mode       49670 non-null  object
#  10  Country         49670 non-null  object
#  11  Order Date      49670 non-null  datetime64[ns]
#  12  Ship Date       49670 non-null  datetime64[ns]
#  13  Market          49670 non-null  object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(8)
# memory usage: 5.3+ MB
